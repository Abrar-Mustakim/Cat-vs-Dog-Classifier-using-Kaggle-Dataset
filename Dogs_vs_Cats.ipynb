# %%
#https://www.kaggle.com/c/dogs-vs-cats/data
# !wget --no-check-certificate https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# Out:
# --2022-01-17 14:00:20--  https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.70.128, 74.125.132.128, 74.125.69.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.70.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68606236 (65M) [application/zip]
# Saving to: ‘cats_and_dogs_filtered.zip.1’
#
# cats_and_dogs_filte 100%[===================>]  65.43M   213MB/s    in 0.3s
#
# 2022-01-17 14:00:20 (213 MB/s) - ‘cats_and_dogs_filtered.zip.1’ saved [68606236/68606236]

# %%
#unzip the packages

import zipfile

zip = zipfile.ZipFile("./cats_and_dogs_filtered.zip")
zip.extractall("./cats_and_dogs_filtered")
zip.close()

# %%
import tensorflow as tf
import numpy as np 
from tensorflow import keras

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_data = ImageDataGenerator(rescale=1/255)

train_gen = train_data.flow_from_directory(
    "./cats_and_dogs_filtered/cats_and_dogs_filtered/train",
    target_size=(150,150),
    batch_size = 20,
    class_mode="binary"
)
# Out:
# Found 2000 images belonging to 2 classes.

# %%
validation_data = ImageDataGenerator(rescale=1/255)

validation_gen = train_data.flow_from_directory(
    "./cats_and_dogs_filtered/cats_and_dogs_filtered/validation",
    target_size=(150,150),
    batch_size = 20,
    class_mode="binary"
)
# Out:
# Found 1000 images belonging to 2 classes.

# %%
model = tf.keras.models.Sequential([
                tf.keras.layers.Conv2D(16, (3,3), activation="relu", input_shape=(150,150,3)),
                tf.keras.layers.MaxPooling2D(2,2),
                tf.keras.layers.Conv2D(32, (3,3), activation="relu"),
                tf.keras.layers.MaxPooling2D(2,2),
                tf.keras.layers.Conv2D(64, (3,3), activation="relu"),
                tf.keras.layers.MaxPooling2D(2,2),
                tf.keras.layers.Flatten(),
                tf.keras.layers.Dense(512, activation="relu"),
                tf.keras.layers.Dense(1, activation="sigmoid")

                                    
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 18496)             0
#
#  dense (Dense)               (None, 512)               9470464
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 9,494,561
# Trainable params: 9,494,561
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import RMSprop 
model.compile(loss="binary_crossentropy",
              optimizer=RMSprop(learning_rate=0.001),
              metrics=["accuracy"])

# %%
history = model.fit_generator(
    train_gen,
    steps_per_epoch=100,
    epochs=20,
    validation_data = validation_gen,
    validation_steps=50,
    verbose=2
)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   import sys
# Epoch 1/20
# 100/100 - 10s - loss: 0.0438 - accuracy: 0.9905 - val_loss: 1.9763 - val_accuracy: 0.7220 - 10s/epoch - 104ms/step
# Epoch 2/20
# 100/100 - 10s - loss: 0.0556 - accuracy: 0.9920 - val_loss: 2.3510 - val_accuracy: 0.7260 - 10s/epoch - 102ms/step
# Epoch 3/20
# 100/100 - 10s - loss: 0.0590 - accuracy: 0.9910 - val_loss: 2.3148 - val_accuracy: 0.7250 - 10s/epoch - 97ms/step
# Epoch 4/20
# 100/100 - 10s - loss: 0.0322 - accuracy: 0.9920 - val_loss: 2.7161 - val_accuracy: 0.7380 - 10s/epoch - 95ms/step
# Epoch 5/20
# 100/100 - 10s - loss: 0.0334 - accuracy: 0.9925 - val_loss: 2.3575 - val_accuracy: 0.7290 - 10s/epoch - 96ms/step
# Epoch 6/20
# 100/100 - 10s - loss: 0.0482 - accuracy: 0.9925 - val_loss: 2.4650 - val_accuracy: 0.7250 - 10s/epoch - 98ms/step
# Epoch 7/20
# 100/100 - 10s - loss: 0.0693 - accuracy: 0.9900 - val_loss: 2.2949 - val_accuracy: 0.7220 - 10s/epoch - 96ms/step
# Epoch 8/20
# 100/100 - 10s - loss: 0.0265 - accuracy: 0.9925 - val_loss: 2.9105 - val_accuracy: 0.7310 - 10s/epoch - 100ms/step
# Epoch 9/20
# 100/100 - 10s - loss: 0.0645 - accuracy: 0.9900 - val_loss: 4.0748 - val_accuracy: 0.6870 - 10s/epoch - 100ms/step
# Epoch 10/20
# 100/100 - 10s - loss: 0.0318 - accuracy: 0.9940 - val_loss: 3.0636 - val_accuracy: 0.7040 - 10s/epoch - 100ms/step
# Epoch 11/20
# 100/100 - 10s - loss: 0.0050 - accuracy: 0.9975 - val_loss: 3.4595 - val_accuracy: 0.7310 - 10s/epoch - 100ms/step
# Epoch 12/20
# 100/100 - 10s - loss: 0.1285 - accuracy: 0.9900 - val_loss: 2.1472 - val_accuracy: 0.6990 - 10s/epoch - 100ms/step
# Epoch 13/20
# 100/100 - 10s - loss: 0.0266 - accuracy: 0.9960 - val_loss: 3.0736 - val_accuracy: 0.6980 - 10s/epoch - 99ms/step
# Epoch 14/20
# 100/100 - 10s - loss: 0.0123 - accuracy: 0.9990 - val_loss: 3.6090 - val_accuracy: 0.6910 - 10s/epoch - 99ms/step
# Epoch 15/20
# 100/100 - 10s - loss: 0.0127 - accuracy: 0.9955 - val_loss: 3.9230 - val_accuracy: 0.7060 - 10s/epoch - 100ms/step
# Epoch 16/20
# 100/100 - 12s - loss: 0.0384 - accuracy: 0.9935 - val_loss: 3.1809 - val_accuracy: 0.7170 - 12s/epoch - 120ms/step
# Epoch 17/20
# 100/100 - 10s - loss: 0.0067 - accuracy: 0.9980 - val_loss: 4.2680 - val_accuracy: 0.7010 - 10s/epoch - 99ms/step
# Epoch 18/20
# 100/100 - 10s - loss: 0.0088 - accuracy: 0.9970 - val_loss: 3.4822 - val_accuracy: 0.7090 - 10s/epoch - 99ms/step
# Epoch 19/20
# 100/100 - 10s - loss: 0.0118 - accuracy: 0.9980 - val_loss: 12.8913 - val_accuracy: 0.5560 - 10s/epoch - 99ms/step
# Epoch 20/20
# 100/100 - 10s - loss: 0.0753 - accuracy: 0.9930 - val_loss: 3.7383 - val_accuracy: 0.7130 - 10s/epoch - 100ms/step

# %%
from google.colab import files 
from keras.preprocessing import image 
import matplotlib.pyplot as plt

upload = files.upload()

for fn in upload.keys():
  path = "/content/"+fn 
  img = image.load_img(path, target_size=(150,150))
  plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size=5)
  print(classes[0])

  if classes[0] > 0.5:
    
    print(fn+" -This is a DOG")
  else:
    
    print(fn+"-This is a CAT")
# Out:
#      <input type="file" id="files-72f4199b-d22b-4c5c-abb9-3a51447911a4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-72f4199b-d22b-4c5c-abb9-3a51447911a4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 6.jpg to 6.jpg
# [1.]
# 6.jpg -This is a DOG
